# %% [markdown]
# ## **Insurance Data EDA and stats**

# %%
import os
import sys

system_path = os.path.abspath("..")
if system_path not in sys.path:
    sys.path.append(system_path)

# %load_ext autoreload
# %autoreload 2

# %%
from src.eda_analysis import InsuranceEDA

# %%
eda = InsuranceEDA()

# %%
insurance_data = eda.load_data('../data/raw/MachineLearningRating_v3.txt')
insurance_data
# Out:
# e:\Courses\10 Academy\Week 3\end-to-end-insurance-risk-analytics-predictive-modeling\src\eda_analysis.py:37: DtypeWarning: Columns (32,37) have mixed types. Specify dtype option on import or set low_memory=False.
#   self.data = pd.read_csv(data_path, sep='|', encoding='utf-8')
#          UnderwrittenCoverID  PolicyID     TransactionMonth  IsVATRegistered  \
# 0                     145249     12827  2015-03-01 00:00:00             True
# 1                     145249     12827  2015-05-01 00:00:00             True
# 2                     145249     12827  2015-07-01 00:00:00             True
# 3                     145255     12827  2015-05-01 00:00:00             True
# 4                     145255     12827  2015-07-01 00:00:00             True
# ...                      ...       ...                  ...              ...
# 1000093                31520       389  2015-04-01 00:00:00            False
# 1000094                31520       389  2015-06-01 00:00:00            False
# ...

# %%
eda.dataset_info()
# Out:
# Dataset Shape: (1000098, 52)
#
# Data Types:
# UnderwrittenCoverID           int64
# PolicyID                      int64
# TransactionMonth             object
# IsVATRegistered                bool
# Citizenship                  object
# LegalType                    object
# Title                        object
# Language                     object
# Bank                         object
# AccountType                  object
# MaritalStatus                object
# Gender                       object
# Country                      object
# Province                     object
# PostalCode                    int64
# MainCrestaZone               object
# SubCrestaZone                object
# ItemType                     object
# mmcode                      float64
# VehicleType                  object
# RegistrationYear              int64
# make                         object
# Model                        object
# Cylinders                   float64
# cubiccapacity               float64
# ...
